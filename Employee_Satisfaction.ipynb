# %% [markdown]
# <a href="https://colab.research.google.com/github/yakupusame/Employee-Attrition/blob/master/Employee_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('Attrition10Year.csv')

# %%
dataset.head(10)

#employee id
#employee record date ( year of data)
#birth date
#hire date
#termination date
#age
#length of service
#city
#department
#job title
#store number
#gender
#termination reason
#termination type
#status year
#status
#business unit
# Out:
#    EmployeeID   recorddate_key birthdate_key  ... STATUS_YEAR  STATUS  BUSINESS_UNIT
# 0        1318  12/31/2006 0:00      1/3/1954  ...      2006.0  ACTIVE     HEADOFFICE
# 1        1318  12/31/2007 0:00      1/3/1954  ...      2007.0  ACTIVE     HEADOFFICE
# 2        1318  12/31/2008 0:00      1/3/1954  ...      2008.0  ACTIVE     HEADOFFICE
# 3        1318  12/31/2009 0:00      1/3/1954  ...      2009.0  ACTIVE     HEADOFFICE
# 4        1318  12/31/2010 0:00      1/3/1954  ...      2010.0  ACTIVE     HEADOFFICE
# 5        1318  12/31/2011 0:00      1/3/1954  ...      2011.0  ACTIVE     HEADOFFICE
# 6        1318  12/31/2012 0:00      1/3/1954  ...      2012.0  ACTIVE     HEADOFFICE
# 7        1318  12/31/2013 0:00      1/3/1954  ...      2013.0  ACTIVE     HEADOFFICE
# 8        1318  12/31/2014 0:00      1/3/1954  ...      2014.0  ACTIVE     HEADOFFICE
# 9        1318  12/31/2015 0:00      1/3/1954  ...      2015.0  ACTIVE     HEADOFFICE
#
# [10 rows x 18 columns]

# %%
dataset.tail(10)
# Out:
#        EmployeeID   recorddate_key  ...  STATUS BUSINESS_UNIT
# 14157        3696  12/31/2007 0:00  ...  ACTIVE        STORES
# 14158        3696  12/31/2008 0:00  ...  ACTIVE        STORES
# 14159        3696  12/31/2009 0:00  ...  ACTIVE        STORES
# 14160        3696  12/31/2010 0:00  ...  ACTIVE        STORES
# 14161        3696  12/31/2011 0:00  ...  ACTIVE        STORES
# 14162        3696  12/31/2012 0:00  ...  ACTIVE        STORES
# 14163        3696  12/31/2013 0:00  ...  ACTIVE        STORES
# 14164        3696  12/31/2014 0:00  ...  ACTIVE        STORES
# 14165        3696  12/31/2015 0:00  ...  ACTIVE        STORES
# 14166        3697           12/31/  ...     NaN           NaN
#
# [10 rows x 18 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14167 entries, 0 to 14166
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           14167 non-null  int64
#  1   recorddate_key       14167 non-null  object
#  2   birthdate_key        14166 non-null  object
#  3   orighiredate_key     14166 non-null  object
#  4   terminationdate_key  14166 non-null  object
#  5   age                  14166 non-null  float64
#  6   length_of_service    14166 non-null  float64
#  7   city_name            14166 non-null  object
#  8   department_name      14166 non-null  object
#  9   job_title            14166 non-null  object
#  10  store_name           14166 non-null  float64
#  11  gender_short         14166 non-null  object
#  12  gender_full          14166 non-null  object
#  13  termreason_desc      14166 non-null  object
#  14  termtype_desc        14166 non-null  object
#  15  STATUS_YEAR          14166 non-null  float64
#  16  STATUS               14166 non-null  object
#  17  BUSINESS_UNIT        14166 non-null  object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 1.9+ MB

# %%
dataset.describe()
# Out:
#          EmployeeID           age  ...    store_name   STATUS_YEAR
# count  14167.000000  14166.000000  ...  14166.000000  14166.000000
# mean    2581.226865     55.182409  ...     27.506494   2010.220740
# std      664.143149      4.514014  ...     13.183001      2.882114
# min     1318.000000     39.000000  ...      1.000000   2006.000000
# 25%     2024.000000     52.000000  ...     17.000000   2008.000000
# 50%     2592.000000     55.000000  ...     29.000000   2010.000000
# 75%     3167.000000     58.000000  ...     41.000000   2013.000000
# max     3697.000000     65.000000  ...     46.000000   2015.000000
#
# [8 rows x 5 columns]

# %%
dataset.head(5)
# Out:
#    EmployeeID   recorddate_key birthdate_key  ... STATUS_YEAR  STATUS  BUSINESS_UNIT
# 0        1318  12/31/2006 0:00      1/3/1954  ...      2006.0  ACTIVE     HEADOFFICE
# 1        1318  12/31/2007 0:00      1/3/1954  ...      2007.0  ACTIVE     HEADOFFICE
# 2        1318  12/31/2008 0:00      1/3/1954  ...      2008.0  ACTIVE     HEADOFFICE
# 3        1318  12/31/2009 0:00      1/3/1954  ...      2009.0  ACTIVE     HEADOFFICE
# 4        1318  12/31/2010 0:00      1/3/1954  ...      2010.0  ACTIVE     HEADOFFICE
#
# [5 rows x 18 columns]

# %%
dataset.columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
dataset.isnull().sum()
#ns.heatmap(employee_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# EmployeeID             0
# recorddate_key         0
# birthdate_key          1
# orighiredate_key       1
# terminationdate_key    1
# age                    1
# length_of_service      1
# city_name              1
# department_name        1
# job_title              1
# store_name             1
# gender_short           1
# gender_full            1
# termreason_desc        1
# termtype_desc          1
# STATUS_YEAR            1
# STATUS                 1
# BUSINESS_UNIT          1
# dtype: int64

# %%
dataset.hist(bins = 30, figsize = (20,20), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feb484963c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb484295f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb483db860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb4838aac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feb483bcd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feb4836df98>]],
#       dtype=object)

# %%
dataset.shape
# Out:
# (14167, 18)

# %%
dataset.describe(include=['O'])
# Out:
#          recorddate_key birthdate_key  ...  STATUS BUSINESS_UNIT
# count             14167         14166  ...   14166         14166
# unique               11          1443  ...       1             2
# top     12/31/2006 0:00     4/27/1956  ...  ACTIVE        STORES
# freq               1692            40  ...   14166         13650
#
# [4 rows x 13 columns]

# %%
dataset.job_title.value_counts()
# Out:
# Meat Cutter                        7554
# Produce Clerk                      2421
# Dairy Person                        825
# Baker                               557
# Shelf Stocker                       411
# Cashier                             326
# Customer Service Manager            276
# Meats Manager                       262
# Produce Manager                     257
# Processed Foods Manager             257
# Bakery Manager                      256
# Store Manager                       240
# Recruiter                            54
# HRIS Analyst                         47
# Accounting Clerk                     45
# Benefits Admin                       30
# Accounts Receiveable Clerk           26
# Labor Relations Analyst              25
# Trainer                              22
# Accounts Payable Clerk               22
# Auditor                              17
# Investment Analyst                   17
# Compensation Analyst                 17
# Systems Analyst                      15
# Corporate Lawyer                     14
# Exec Assistant, Legal Counsel        10
# VP Human Resources                   10
# VP Finance                           10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# CEO                                  10
# Exec Assistant, Finance              10
# Exec Assistant, VP Stores            10
# VP Stores                            10
# Director, Recruitment                10
# Legal Counsel                        10
# Dairy Manager                         8
# Director, HR Technology               8
# Director, Accounts Payable            8
# Director, Accounts Receivable         8
# Director, Employee Records            8
# Director, Accounting                  8
# Director, Compensation                3
# Director, Investments                 3
# Director, Training                    3
# Director, Labor Relations             3
# Director, Audit                       3
# Name: job_title, dtype: int64

# %%
employee = ['Meat Cutter', 'Dairy Person', 'Produce Clerk', 'Baker', 'Cashier',
            'Shelf Stocker', 'Recruiter', 'HRIS Analyst', 'Accounting Clerk',
            'Benefits Admin', 'Labor Relations Analyst', 'Accounts Receiveable Clerk',
            'Accounts Payable Clerk', 'Auditor', 'Compensation Analyst',
            'Investment Analyst', 'Systems Analyst', 'Corporate Lawyer', 'Legal Counsel']

manager = ['Customer Service Manager', 'Processed Foods Manager', 'Meats Manager',
           'Bakery Manager', 'Produce Manager', 'Store Manager', 'Trainer', 'Dairy Manager']

executive = ['Exec Assistant, Finance', 'Exec Assistant, Legal Counsel',
             'CHief Information Officer', 'CEO', 'Exec Assistant, Human Resources',
             'Exec Assistant, VP Stores']

board = ['VP Stores', 'Director, Recruitment', 'VP Human Resources', 'VP Finance',
         'Director, Accounts Receivable', 'Director, Accounting',
         'Director, Employee Records', 'Director, Accounts Payable',
         'Director, HR Technology', 'Director, Investments',
         'Director, Labor Relations', 'Director, Audit', 'Director, Training',
         'Director, Compensation']

# %%
total = len(employee) + len(manager) + len(executive) + len(board)
print('Total jobs categorised:', total, 'out of 47')
# Out:
# Total jobs categorised: 47 out of 47
